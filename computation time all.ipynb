# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import seaborn as sns
plotdata = pd.DataFrame({
    "MVG":[4.835, 6.028, 7.656, 8.397, 5.355,3.356,10.03],
    "OC_SVM":[10.530, 8.039, 9.802, 12.666, 17.203,6.815,20.036],
    "iForest":[9.07, 6.176, 8.184, 10.038, 5.093,3.079,14.32]
    },
    index=["EfficientNet B3", "EfficientNet B4", "EfficientNet B5", "EfficientNet B6", "MobileNet V2","VGG 16","Xception"]
)

plotdata.plot(kind="bar", color=['C1','C0','C2'], rot=0, fontsize=18)
#plt.title("Computation Time for Anomaly Models",fontsize=18)
plt.xlabel("Network Model",fontsize=18)
plt.ylabel(" Computation time (s)",fontsize=18)
plt.legend(loc="upper left", fontsize=18)
fig = plt.gcf()
fig.set_size_inches((20, 11), forward=False)
plt.savefig('Computation_Time_for_Anomaly_Models.svg',dpi=2160)
plt.show()
