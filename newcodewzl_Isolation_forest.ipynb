# %%
# %%time
import cv2
import os
import numpy as np
import tensorflow as tf
import keras
from sklearn.mixture import GaussianMixture
from sklearn import mixture
from scipy.spatial import distance
from tqdm.notebook import tqdm
import seaborn
import matplotlib.pyplot as plt
#from ipywidgets import IntProgress
# Out:
# CPU times: user 2.34 s, sys: 506 ms, total: 2.85 s
# Wall time: 5.34 s

# %%
# %%time
def load_images_from_folder(folder):
    images = []
    for filename in tqdm(sorted(os.listdir(folder))):
        img = cv2.imread(os.path.join(folder,filename))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224, 224))
        if img is not None:
            images.append(img)
    return np.array(images)

path = load_images_from_folder("/home/ws575033/thesis_nb/Train_fin/")
path.shape
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]
# CPU times: user 6.6 s, sys: 2.82 s, total: 9.42 s
# Wall time: 535 ms
# (110, 224, 224, 3)

# %%
#####Model for extracting features
mobilenetv2 = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    alpha=1.0,
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
vgg16 = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
Xception = tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
resnet50v2 = tf.keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(96, 96, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
Inception_ResNetv2 = tf.keras.applications.InceptionResNetV2(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(96, 96, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
effnetB3 = tf.keras.applications.EfficientNetB3(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)
#effnetB3.summary()
model = effnetB3  # create the original model
inputs = (224, 224, 3)
layer_name = 'block6f_add'
intermediate_layer_modelb3 = keras.Model(inputs=model.input,
                                        outputs=model.get_layer(layer_name).output)
#intermediate_output = intermediate_layer_model(path)
intermediate_layer_modelb3.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Total params: 6,887,029
# Trainable params: 6,819,118
# Non-trainable params: 67,911
# __________________________________________________________________________________________________

# %%
effnetB4 = tf.keras.applications.EfficientNetB4(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)
#effnetB4.summary()
model = effnetB4  # create the original model
inputs = (224, 224, 3)
layer_name = 'block6h_add'
intermediate_layer_modelb4 = keras.Model(inputs=model.input,
                                       outputs=model.get_layer(layer_name).output)
#intermediate_output = intermediate_layer_model(path)
intermediate_layer_modelb4.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Total params: 12,374,763
# Trainable params: 12,272,212
# Non-trainable params: 102,551
# __________________________________________________________________________________________________

# %%
effnetB5 = tf.keras.applications.EfficientNetB5(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)
#effnetB5.summary()
model = effnetB5  # create the original model
inputs = (224, 224, 3)
layer_name = 'block6i_add'
intermediate_layer_modelb5 = keras.Model(inputs=model.input,
                                       outputs=model.get_layer(layer_name).output)
#intermediate_output = intermediate_layer_model(path)
intermediate_layer_modelb5.summary()

# %%
effnetB6 = tf.keras.applications.EfficientNetB6(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)
#effnetB6.summary()
model = effnetB6  # create the original model
inputs = (224, 224, 3)
layer_name = 'block6k_add'
intermediate_layer_modelb6 = keras.Model(inputs=model.input,
                                       outputs=model.get_layer(layer_name).output)
#intermediate_output = intermediate_layer_model(path)
intermediate_layer_modelb6.summary()

# %%
effnetB7 = tf.keras.applications.EfficientNetB7(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(96, 96, 3),
    pooling=None,
    #classes=1000,
    #classifier_activation="softmax",
)

# %%
# %%time

#model predict
features = Xception.predict(
    path,
    batch_size=None,
    verbose=0,
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
)
features.shape
# Out:
# CPU times: user 21.1 s, sys: 5.61 s, total: 26.7 s
# Wall time: 1.31 s
# (110, 7, 7, 2048)

# %%
features_linear = features.reshape(-1, features.shape[-1])
features_linear.shape
# Out:
# (5390, 2048)

# %%
# %%time
from sklearn.ensemble import IsolationForest
cls = IsolationForest(random_state=3).fit(features_linear)
# Out:
# CPU times: user 11.4 s, sys: 3.16 ms, total: 11.4 s
# Wall time: 11.4 s

# %%
dir(cls)

# %%
# from sklearn.mixture import GaussianMixture
# #Gaussian mixture model
# gm = GaussianMixture(n_components=1, random_state=0).fit(features_linear)
# #print("gm", gm)
# #mvg = gm.sample()
# #plt.imshow(mvg)
# #seaborn.distplot(mvg)
# print("gm_means", gm.means_.shape)
# print("gm_covariance", gm.covariances_.shape)
# inv_cov = np.linalg.inv(gm.covariances_)
# #print("inv_covariance", inv_cov)

# %%
# %%time

###################Test per frame###########################
test_image = load_images_from_folder("/home/ws575033/thesis_nb/Test_fin")
print("Test_image", test_image.shape)
dist_list=[]
for i in range(len(test_image)):
    tes = test_image[i]
    tes = np.expand_dims(tes, axis=0)
    #extract features
    features2 = Xception.predict(
    tes,
    batch_size=None,
    verbose=0,
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
    )
    #print(features2.shape)

    #for i in range(features2.shape[0]):
    
    features2_linear = features2.reshape(-1, features2.shape[-1])
    print("features2_shape", features2_linear.shape)

    #Mahalonobis distance
    maha = cls.decision_function(features2_linear)
    #seaborn.distplot(maha)
    #plt.imshow(maha)
    #seaborn.distplot(gm.means_)
    #plt.imshow(gm.means_)
    #print("mahalonobis distance shape", maha.shape)
    #print("mahalonobis distance", maha.reshape(-1, 7))
    print(i, "mahalonobis distance ------------------------------>>>>>>>", maha.max())
    
    dist_list.append(maha.max())
dist_list = np.array(dist_list)
dist_list.shape
# Out:
#   0%|          | 0/422 [00:00<?, ?it/s]
# Test_image (422, 224, 224, 3)
# features2_shape (49, 2048)
# 0 mahalonobis distance ------------------------------>>>>>>> 0.15335163044099132
# features2_shape (49, 2048)
# 1 mahalonobis distance ------------------------------>>>>>>> 0.15415980202990331
# features2_shape (49, 2048)
# 2 mahalonobis distance ------------------------------>>>>>>> 0.1526293774777016
# features2_shape (49, 2048)
# 3 mahalonobis distance ------------------------------>>>>>>> 0.15288882074806104
# features2_shape (49, 2048)
# 4 mahalonobis distance ------------------------------>>>>>>> 0.1540264601905605
# features2_shape (49, 2048)
# 5 mahalonobis distance ------------------------------>>>>>>> 0.15271438759207728
# features2_shape (49, 2048)
# 6 mahalonobis distance ------------------------------>>>>>>> 0.1542465190142182
# features2_shape (49, 2048)
# 7 mahalonobis distance ------------------------------>>>>>>> 0.15335163044099132
# features2_shape (49, 2048)
# 8 mahalonobis distance ------------------------------>>>>>>> 0.15355243440402006
# features2_shape (49, 2048)
# 9 mahalonobis distance ------------------------------>>>>>>> 0.15288882074806104
# features2_shape (49, 2048)
# 10 mahalonobis distance ------------------------------>>>>>>> 0.1516338554987104
# features2_shape (49, 2048)
# 11 mahalonobis distance ------------------------------>>>>>>> 0.15460576471021875
# features2_shape (49, 2048)
# 12 mahalonobis distance ------------------------------>>>>>>> 0.1560679055492919
# features2_shape (49, 2048)
# 13 mahalonobis distance ------------------------------>>>>>>> 0.15595061685128253
# features2_shape (49, 2048)
# 14 mahalonobis distance ------------------------------>>>>>>> 0.15551706226305795
# features2_shape (49, 2048)
# 15 mahalonobis distance ------------------------------>>>>>>> 0.15052624172197582
# features2_shape (49, 2048)
# 16 mahalonobis distance ------------------------------>>>>>>> 0.15274177879996081
# features2_shape (49, 2048)
# 17 mahalonobis distance ------------------------------>>>>>>> 0.1563504229084256
# features2_shape (49, 2048)
# 18 mahalonobis distance ------------------------------>>>>>>> 0.15622172377227894
# features2_shape (49, 2048)
# 19 mahalonobis distance ------------------------------>>>>>>> 0.1560045358067354
# features2_shape (49, 2048)
# 20 mahalonobis distance ------------------------------>>>>>>> 0.16118153918710487
# features2_shape (49, 2048)
# 21 mahalonobis distance ------------------------------>>>>>>> 0.15657465148180472
# features2_shape (49, 2048)
# 22 mahalonobis distance ------------------------------>>>>>>> 0.15908856596148246
# features2_shape (49, 2048)
# 23 mahalonobis distance ------------------------------>>>>>>> 0.15053458373230216
# features2_shape (49, 2048)
# 24 mahalonobis distance ------------------------------>>>>>>> 0.1539577011973407
# features2_shape (49, 2048)
# 25 mahalonobis distance ------------------------------>>>>>>> 0.15562810183905967
# features2_shape (49, 2048)
# 26 mahalonobis distance ------------------------------>>>>>>> 0.15487514025059101
# features2_shape (49, 2048)
# 27 mahalonobis distance ------------------------------>>>>>>> 0.14732300318063668
# features2_shape (49, 2048)
# 28 mahalonobis distance ------------------------------>>>>>>> 0.14934388047344116
# features2_shape (49, 2048)
# 29 mahalonobis distance ------------------------------>>>>>>> 0.14873416409064555
# features2_shape (49, 2048)
# 30 mahalonobis distance ------------------------------>>>>>>> 0.143705893998976
# features2_shape (49, 2048)
# 31 mahalonobis distance ------------------------------>>>>>>> 0.14805035840150693
# features2_shape (49, 2048)
# 32 mahalonobis distance ------------------------------>>>>>>> 0.14579910125804774
# features2_shape (49, 2048)
# 33 mahalonobis distance ------------------------------>>>>>>> 0.14493664411497215
# features2_shape (49, 2048)
# 34 mahalonobis distance ------------------------------>>>>>>> 0.13482177555618896
# features2_shape (49, 2048)
# 35 mahalonobis distance ------------------------------>>>>>>> 0.14515770026742048
# features2_shape (49, 2048)
# 36 mahalonobis distance ------------------------------>>>>>>> 0.15148813626645735
# features2_shape (49, 2048)
# 37 mahalonobis distance ------------------------------>>>>>>> 0.153946087815015
# features2_shape (49, 2048)
# 38 mahalonobis distance ------------------------------>>>>>>> 0.15423986472252965
# features2_shape (49, 2048)
# 39 mahalonobis distance ------------------------------>>>>>>> 0.15783019955555944
# features2_shape (49, 2048)
# 40 mahalonobis distance ------------------------------>>>>>>> 0.15908695241825138
# features2_shape (49, 2048)
# 41 mahalonobis distance ------------------------------>>>>>>> 0.15912143161763082
# features2_shape (49, 2048)
# 42 mahalonobis distance ------------------------------>>>>>>> 0.15965164313366625
# features2_shape (49, 2048)
# 43 mahalonobis distance ------------------------------>>>>>>> 0.1552117296672048
# features2_shape (49, 2048)
# 44 mahalonobis distance ------------------------------>>>>>>> 0.15594712766865776
# features2_shape (49, 2048)
# 45 mahalonobis distance ------------------------------>>>>>>> 0.13686095677183474
# features2_shape (49, 2048)
# 46 mahalonobis distance ------------------------------>>>>>>> 0.14494611811731417
# features2_shape (49, 2048)
# 47 mahalonobis distance ------------------------------>>>>>>> 0.15080163777229405
# features2_shape (49, 2048)
# 48 mahalonobis distance ------------------------------>>>>>>> 0.1386430941655658
# features2_shape (49, 2048)
# 49 mahalonobis distance ------------------------------>>>>>>> 0.1410812773777242
# features2_shape (49, 2048)
# 50 mahalonobis distance ------------------------------>>>>>>> 0.13986748253112952
# features2_shape (49, 2048)
# 51 mahalonobis distance ------------------------------>>>>>>> 0.14683284352831433
# features2_shape (49, 2048)
# 52 mahalonobis distance ------------------------------>>>>>>> 0.14225726755768736
# features2_shape (49, 2048)
# 53 mahalonobis distance ------------------------------>>>>>>> 0.14599437755664285
# features2_shape (49, 2048)
# 54 mahalonobis distance ------------------------------>>>>>>> 0.14007375105105735
# features2_shape (49, 2048)
# 55 mahalonobis distance ------------------------------>>>>>>> 0.13832833742626016
# features2_shape (49, 2048)
# 56 mahalonobis distance ------------------------------>>>>>>> 0.13985676534538483
# features2_shape (49, 2048)
# 57 mahalonobis distance ------------------------------>>>>>>> 0.14456929939768837
# features2_shape (49, 2048)
# 58 mahalonobis distance ------------------------------>>>>>>> 0.14106771825734726
# features2_shape (49, 2048)
# 59 mahalonobis distance ------------------------------>>>>>>> 0.13967549180126965
# features2_shape (49, 2048)
# 60 mahalonobis distance ------------------------------>>>>>>> 0.1377927088053018
# features2_shape (49, 2048)
# 61 mahalonobis distance ------------------------------>>>>>>> 0.13946102076944206
# features2_shape (49, 2048)
# 62 mahalonobis distance ------------------------------>>>>>>> 0.13790240884992838
# features2_shape (49, 2048)
# 63 mahalonobis distance ------------------------------>>>>>>> 0.1392412939674536
# features2_shape (49, 2048)
# 64 mahalonobis distance ------------------------------>>>>>>> 0.13332812059591637
# features2_shape (49, 2048)
# 65 mahalonobis distance ------------------------------>>>>>>> 0.13296160189792122
# features2_shape (49, 2048)
# 66 mahalonobis distance ------------------------------>>>>>>> 0.13319100248754112
# features2_shape (49, 2048)
# 67 mahalonobis distance ------------------------------>>>>>>> 0.14263067694890397
# features2_shape (49, 2048)
# 68 mahalonobis distance ------------------------------>>>>>>> 0.1391331182826967
# features2_shape (49, 2048)
# 69 mahalonobis distance ------------------------------>>>>>>> 0.15111590528328828
# features2_shape (49, 2048)
# 70 mahalonobis distance ------------------------------>>>>>>> 0.1432429019025605
# features2_shape (49, 2048)
# 71 mahalonobis distance ------------------------------>>>>>>> 0.1363232637154264
# features2_shape (49, 2048)
# 72 mahalonobis distance ------------------------------>>>>>>> 0.13863573632808757
# features2_shape (49, 2048)
# 73 mahalonobis distance ------------------------------>>>>>>> 0.13229843540151853
# features2_shape (49, 2048)
# 74 mahalonobis distance ------------------------------>>>>>>> 0.1326608816220946
# features2_shape (49, 2048)
# 75 mahalonobis distance ------------------------------>>>>>>> 0.1390129160585254
# features2_shape (49, 2048)
# 76 mahalonobis distance ------------------------------>>>>>>> 0.13987113141027685
# features2_shape (49, 2048)
# 77 mahalonobis distance ------------------------------>>>>>>> 0.13987113141027685
# features2_shape (49, 2048)
# 78 mahalonobis distance ------------------------------>>>>>>> 0.14400192138306805
# features2_shape (49, 2048)
# 79 mahalonobis distance ------------------------------>>>>>>> 0.1332580228869253
# features2_shape (49, 2048)
# 80 mahalonobis distance ------------------------------>>>>>>> 0.14063466772458683
# features2_shape (49, 2048)
# 81 mahalonobis distance ------------------------------>>>>>>> 0.1384036740169372
# features2_shape (49, 2048)
# 82 mahalonobis distance ------------------------------>>>>>>> 0.14240879443228677
# features2_shape (49, 2048)
# 83 mahalonobis distance ------------------------------>>>>>>> 0.14559766318293937
# features2_shape (49, 2048)
# 84 mahalonobis distance ------------------------------>>>>>>> 0.1393856361917305
# features2_shape (49, 2048)
# 85 mahalonobis distance ------------------------------>>>>>>> 0.1447393925721192
# features2_shape (49, 2048)
# 86 mahalonobis distance ------------------------------>>>>>>> 0.15184388274961358
# features2_shape (49, 2048)
# 87 mahalonobis distance ------------------------------>>>>>>> 0.1513620210441538
# features2_shape (49, 2048)
# 88 mahalonobis distance ------------------------------>>>>>>> 0.14257435452177358
# features2_shape (49, 2048)
# 89 mahalonobis distance ------------------------------>>>>>>> 0.14791819806536521
# features2_shape (49, 2048)
# 90 mahalonobis distance ------------------------------>>>>>>> 0.14965214394087673
# features2_shape (49, 2048)
# 91 mahalonobis distance ------------------------------>>>>>>> 0.15004661240825984
# features2_shape (49, 2048)
# 92 mahalonobis distance ------------------------------>>>>>>> 0.15276664606320733
# features2_shape (49, 2048)
# 93 mahalonobis distance ------------------------------>>>>>>> 0.15344355209863786
# features2_shape (49, 2048)
# 94 mahalonobis distance ------------------------------>>>>>>> 0.15701167573736063
# features2_shape (49, 2048)
# 95 mahalonobis distance ------------------------------>>>>>>> 0.1567566479913592
# features2_shape (49, 2048)
# 96 mahalonobis distance ------------------------------>>>>>>> 0.15651958285841722
# features2_shape (49, 2048)
# 97 mahalonobis distance ------------------------------>>>>>>> 0.15651283180722414
# features2_shape (49, 2048)
# 98 mahalonobis distance ------------------------------>>>>>>> 0.15148619607386438
# features2_shape (49, 2048)
# 99 mahalonobis distance ------------------------------>>>>>>> 0.15667394825666658
# features2_shape (49, 2048)
# 100 mahalonobis distance ------------------------------>>>>>>> 0.1540321166190302
# features2_shape (49, 2048)
# 101 mahalonobis distance ------------------------------>>>>>>> 0.1541748091388329
# features2_shape (49, 2048)
# 102 mahalonobis distance ------------------------------>>>>>>> 0.15287570403171652
# features2_shape (49, 2048)
# 103 mahalonobis distance ------------------------------>>>>>>> 0.15507632433525925
# features2_shape (49, 2048)
# 104 mahalonobis distance ------------------------------>>>>>>> 0.15685874670943728
# features2_shape (49, 2048)
# 105 mahalonobis distance ------------------------------>>>>>>> 0.15417728413072312
# features2_shape (49, 2048)
# 106 mahalonobis distance ------------------------------>>>>>>> 0.15594676360915904
# features2_shape (49, 2048)
# 107 mahalonobis distance ------------------------------>>>>>>> 0.15219010642593261
# features2_shape (49, 2048)
# 108 mahalonobis distance ------------------------------>>>>>>> 0.1484097278253237
# features2_shape (49, 2048)
# 109 mahalonobis distance ------------------------------>>>>>>> 0.14506377627325878
# features2_shape (49, 2048)
# 110 mahalonobis distance ------------------------------>>>>>>> 0.14644433707912458
# features2_shape (49, 2048)
# 111 mahalonobis distance ------------------------------>>>>>>> 0.14881129175858399
# features2_shape (49, 2048)
# 112 mahalonobis distance ------------------------------>>>>>>> 0.15176542029738288
# features2_shape (49, 2048)
# 113 mahalonobis distance ------------------------------>>>>>>> 0.15373424936971353
# features2_shape (49, 2048)
# 114 mahalonobis distance ------------------------------>>>>>>> 0.15614820079950031
# features2_shape (49, 2048)
# 115 mahalonobis distance ------------------------------>>>>>>> 0.15233760877239227
# features2_shape (49, 2048)
# 116 mahalonobis distance ------------------------------>>>>>>> 0.14900717572938094
# features2_shape (49, 2048)
# 117 mahalonobis distance ------------------------------>>>>>>> 0.15174885551946915
# features2_shape (49, 2048)
# 118 mahalonobis distance ------------------------------>>>>>>> 0.15079778604556765
# features2_shape (49, 2048)
# 119 mahalonobis distance ------------------------------>>>>>>> 0.15182372967482777
# features2_shape (49, 2048)
# 120 mahalonobis distance ------------------------------>>>>>>> 0.1525323162128821
# features2_shape (49, 2048)
# 121 mahalonobis distance ------------------------------>>>>>>> 0.15469857156339756
# features2_shape (49, 2048)
# 122 mahalonobis distance ------------------------------>>>>>>> 0.15490128206003306
# features2_shape (49, 2048)
# 123 mahalonobis distance ------------------------------>>>>>>> 0.14934174042145698
# features2_shape (49, 2048)
# 124 mahalonobis distance ------------------------------>>>>>>> 0.15384775723597927
# features2_shape (49, 2048)
# 125 mahalonobis distance ------------------------------>>>>>>> 0.1552806739283985
# features2_shape (49, 2048)
# 126 mahalonobis distance ------------------------------>>>>>>> 0.14705040595237273
# features2_shape (49, 2048)
# 127 mahalonobis distance ------------------------------>>>>>>> 0.1438520383373192
# features2_shape (49, 2048)
# 128 mahalonobis distance ------------------------------>>>>>>> 0.15037347414062552
# features2_shape (49, 2048)
# 129 mahalonobis distance ------------------------------>>>>>>> 0.15600791172995393
# features2_shape (49, 2048)
# 130 mahalonobis distance ------------------------------>>>>>>> 0.15318416767764648
# features2_shape (49, 2048)
# 131 mahalonobis distance ------------------------------>>>>>>> 0.15549330802710365
# features2_shape (49, 2048)
# 132 mahalonobis distance ------------------------------>>>>>>> 0.15198732450968017
# features2_shape (49, 2048)
# 133 mahalonobis distance ------------------------------>>>>>>> 0.1602370081366019
# features2_shape (49, 2048)
# 134 mahalonobis distance ------------------------------>>>>>>> 0.15913137356666807
# features2_shape (49, 2048)
# 135 mahalonobis distance ------------------------------>>>>>>> 0.15770577434330202
# features2_shape (49, 2048)
# 136 mahalonobis distance ------------------------------>>>>>>> 0.1546280972053653
# features2_shape (49, 2048)
# 137 mahalonobis distance ------------------------------>>>>>>> 0.15807884739617029
# features2_shape (49, 2048)
# 138 mahalonobis distance ------------------------------>>>>>>> 0.14952355176445198
# features2_shape (49, 2048)
# 139 mahalonobis distance ------------------------------>>>>>>> 0.15558192080996286
# features2_shape (49, 2048)
# 140 mahalonobis distance ------------------------------>>>>>>> 0.16036829073703956
# features2_shape (49, 2048)
# 141 mahalonobis distance ------------------------------>>>>>>> 0.14998986081217042
# features2_shape (49, 2048)
# 142 mahalonobis distance ------------------------------>>>>>>> 0.15676324371264427
# features2_shape (49, 2048)
# 143 mahalonobis distance ------------------------------>>>>>>> 0.15608788888066583
# features2_shape (49, 2048)
# 144 mahalonobis distance ------------------------------>>>>>>> 0.15428886927195884
# features2_shape (49, 2048)
# 145 mahalonobis distance ------------------------------>>>>>>> 0.15869692067529595
# features2_shape (49, 2048)
# 146 mahalonobis distance ------------------------------>>>>>>> 0.15950539137236175
# features2_shape (49, 2048)
# 147 mahalonobis distance ------------------------------>>>>>>> 0.1576287519714732
# features2_shape (49, 2048)
# 148 mahalonobis distance ------------------------------>>>>>>> 0.15476632915727012
# features2_shape (49, 2048)
# 149 mahalonobis distance ------------------------------>>>>>>> 0.1583180794661786
# features2_shape (49, 2048)
# 150 mahalonobis distance ------------------------------>>>>>>> 0.1573019153286615
# features2_shape (49, 2048)
# 151 mahalonobis distance ------------------------------>>>>>>> 0.15597436910999135
# features2_shape (49, 2048)
# 152 mahalonobis distance ------------------------------>>>>>>> 0.1563526649562894
# features2_shape (49, 2048)
# 153 mahalonobis distance ------------------------------>>>>>>> 0.15951448729101875
# features2_shape (49, 2048)
# 154 mahalonobis distance ------------------------------>>>>>>> 0.157305860924849
# features2_shape (49, 2048)
# 155 mahalonobis distance ------------------------------>>>>>>> 0.15680902304341526
# features2_shape (49, 2048)
# 156 mahalonobis distance ------------------------------>>>>>>> 0.15813887982306912
# features2_shape (49, 2048)
# 157 mahalonobis distance ------------------------------>>>>>>> 0.16010481204299787
# features2_shape (49, 2048)
# 158 mahalonobis distance ------------------------------>>>>>>> 0.15721784572013037
# features2_shape (49, 2048)
# 159 mahalonobis distance ------------------------------>>>>>>> 0.15667378138490468
# features2_shape (49, 2048)
# 160 mahalonobis distance ------------------------------>>>>>>> 0.15684812436256673
# features2_shape (49, 2048)
# 161 mahalonobis distance ------------------------------>>>>>>> 0.15685152103567412
# features2_shape (49, 2048)
# 162 mahalonobis distance ------------------------------>>>>>>> 0.1547760173869816
# features2_shape (49, 2048)
# 163 mahalonobis distance ------------------------------>>>>>>> 0.1500857961678444
# features2_shape (49, 2048)
# 164 mahalonobis distance ------------------------------>>>>>>> 0.1540216027094114
# features2_shape (49, 2048)
# 165 mahalonobis distance ------------------------------>>>>>>> 0.15621950930444567
# features2_shape (49, 2048)
# 166 mahalonobis distance ------------------------------>>>>>>> 0.157002810855503
# features2_shape (49, 2048)
# 167 mahalonobis distance ------------------------------>>>>>>> 0.15115417885835575
# features2_shape (49, 2048)
# 168 mahalonobis distance ------------------------------>>>>>>> 0.14234472523590025
# features2_shape (49, 2048)
# 169 mahalonobis distance ------------------------------>>>>>>> 0.1424568797562205
# features2_shape (49, 2048)
# 170 mahalonobis distance ------------------------------>>>>>>> 0.13821527364922964
# features2_shape (49, 2048)
# 171 mahalonobis distance ------------------------------>>>>>>> 0.1423616136537823
# features2_shape (49, 2048)
# 172 mahalonobis distance ------------------------------>>>>>>> 0.14118980711212548
# features2_shape (49, 2048)
# 173 mahalonobis distance ------------------------------>>>>>>> 0.13918453959004
# features2_shape (49, 2048)
# 174 mahalonobis distance ------------------------------>>>>>>> 0.12836169984237783
# features2_shape (49, 2048)
# 175 mahalonobis distance ------------------------------>>>>>>> 0.1407501344845477
# features2_shape (49, 2048)
# 176 mahalonobis distance ------------------------------>>>>>>> 0.1462217928876
# features2_shape (49, 2048)
# 177 mahalonobis distance ------------------------------>>>>>>> 0.15703389060853717
# features2_shape (49, 2048)
# 178 mahalonobis distance ------------------------------>>>>>>> 0.15338124528104552
# features2_shape (49, 2048)
# 179 mahalonobis distance ------------------------------>>>>>>> 0.15316694295017175
# features2_shape (49, 2048)
# 180 mahalonobis distance ------------------------------>>>>>>> 0.14428748070578773
# features2_shape (49, 2048)
# 181 mahalonobis distance ------------------------------>>>>>>> 0.133404099412267
# features2_shape (49, 2048)
# 182 mahalonobis distance ------------------------------>>>>>>> 0.11776570115617979
# features2_shape (49, 2048)
# 183 mahalonobis distance ------------------------------>>>>>>> 0.12151224398262955
# features2_shape (49, 2048)
# 184 mahalonobis distance ------------------------------>>>>>>> 0.1279906299641806
# features2_shape (49, 2048)
# 185 mahalonobis distance ------------------------------>>>>>>> 0.1321729940765894
# features2_shape (49, 2048)
# 186 mahalonobis distance ------------------------------>>>>>>> 0.1381051934477539
# features2_shape (49, 2048)
# 187 mahalonobis distance ------------------------------>>>>>>> 0.1375656950244083
# features2_shape (49, 2048)
# 188 mahalonobis distance ------------------------------>>>>>>> 0.14075695971783952
# features2_shape (49, 2048)
# 189 mahalonobis distance ------------------------------>>>>>>> 0.1484184722683367
# features2_shape (49, 2048)
# 190 mahalonobis distance ------------------------------>>>>>>> 0.14621107517369364
# features2_shape (49, 2048)
# 191 mahalonobis distance ------------------------------>>>>>>> 0.1551655866884903
# features2_shape (49, 2048)
# 192 mahalonobis distance ------------------------------>>>>>>> 0.15633833660328195
# features2_shape (49, 2048)
# 193 mahalonobis distance ------------------------------>>>>>>> 0.15504041877224628
# features2_shape (49, 2048)
# 194 mahalonobis distance ------------------------------>>>>>>> 0.15581266323239262
# features2_shape (49, 2048)
# 195 mahalonobis distance ------------------------------>>>>>>> 0.15352138969019158
# features2_shape (49, 2048)
# 196 mahalonobis distance ------------------------------>>>>>>> 0.1617290257961197
# features2_shape (49, 2048)
# 197 mahalonobis distance ------------------------------>>>>>>> 0.15562613659872454
# features2_shape (49, 2048)
# 198 mahalonobis distance ------------------------------>>>>>>> 0.16198721477222677
# features2_shape (49, 2048)
# 199 mahalonobis distance ------------------------------>>>>>>> 0.15377770163339416
# features2_shape (49, 2048)
# 200 mahalonobis distance ------------------------------>>>>>>> 0.15572540718710232
# features2_shape (49, 2048)
# 201 mahalonobis distance ------------------------------>>>>>>> 0.15097376758752185
# features2_shape (49, 2048)
# 202 mahalonobis distance ------------------------------>>>>>>> 0.14884611455165214
# features2_shape (49, 2048)
# 203 mahalonobis distance ------------------------------>>>>>>> 0.14822143578852315
# features2_shape (49, 2048)
# 204 mahalonobis distance ------------------------------>>>>>>> 0.14907897793862435
# features2_shape (49, 2048)
# 205 mahalonobis distance ------------------------------>>>>>>> 0.14957298493423327
# features2_shape (49, 2048)
# 206 mahalonobis distance ------------------------------>>>>>>> 0.1460890422146109
# features2_shape (49, 2048)
# 207 mahalonobis distance ------------------------------>>>>>>> 0.14753097505598806
# features2_shape (49, 2048)
# 208 mahalonobis distance ------------------------------>>>>>>> 0.14965752026682394
# features2_shape (49, 2048)
# 209 mahalonobis distance ------------------------------>>>>>>> 0.14591262842768404
# features2_shape (49, 2048)
# 210 mahalonobis distance ------------------------------>>>>>>> 0.14570684226008845
# features2_shape (49, 2048)
# 211 mahalonobis distance ------------------------------>>>>>>> 0.15431887458596416
# features2_shape (49, 2048)
# 212 mahalonobis distance ------------------------------>>>>>>> 0.1582556359582244
# features2_shape (49, 2048)
# 213 mahalonobis distance ------------------------------>>>>>>> 0.1547904938590825
# features2_shape (49, 2048)
# 214 mahalonobis distance ------------------------------>>>>>>> 0.1561615818647425
# features2_shape (49, 2048)
# 215 mahalonobis distance ------------------------------>>>>>>> 0.15524717411240918
# features2_shape (49, 2048)
# 216 mahalonobis distance ------------------------------>>>>>>> 0.15422389201382747
# features2_shape (49, 2048)
# 217 mahalonobis distance ------------------------------>>>>>>> 0.1488648819146503
# features2_shape (49, 2048)
# 218 mahalonobis distance ------------------------------>>>>>>> 0.14686675668578936
# features2_shape (49, 2048)
# 219 mahalonobis distance ------------------------------>>>>>>> 0.15373833596833986
# features2_shape (49, 2048)
# 220 mahalonobis distance ------------------------------>>>>>>> 0.15519689288486155
# features2_shape (49, 2048)
# 221 mahalonobis distance ------------------------------>>>>>>> 0.1544866580192511
# features2_shape (49, 2048)
# 222 mahalonobis distance ------------------------------>>>>>>> 0.15078390968162225
# features2_shape (49, 2048)
# 223 mahalonobis distance ------------------------------>>>>>>> 0.15972498201145008
# features2_shape (49, 2048)
# 224 mahalonobis distance ------------------------------>>>>>>> 0.15904019556246313
# features2_shape (49, 2048)
# 225 mahalonobis distance ------------------------------>>>>>>> 0.15675789485064906
# features2_shape (49, 2048)
# 226 mahalonobis distance ------------------------------>>>>>>> 0.1519475722897083
# features2_shape (49, 2048)
# 227 mahalonobis distance ------------------------------>>>>>>> 0.15147627847164252
# features2_shape (49, 2048)
# 228 mahalonobis distance ------------------------------>>>>>>> 0.1519475722897083
# features2_shape (49, 2048)
# 229 mahalonobis distance ------------------------------>>>>>>> 0.1519475722897083
# features2_shape (49, 2048)
# 230 mahalonobis distance ------------------------------>>>>>>> 0.1519475722897083
# features2_shape (49, 2048)
# 231 mahalonobis distance ------------------------------>>>>>>> 0.1519475722897083
# features2_shape (49, 2048)
# 232 mahalonobis distance ------------------------------>>>>>>> 0.1519964071731828
# features2_shape (49, 2048)
# 233 mahalonobis distance ------------------------------>>>>>>> 0.14957415812420216
# features2_shape (49, 2048)
# 234 mahalonobis distance ------------------------------>>>>>>> 0.15122298492454417
# features2_shape (49, 2048)
# 235 mahalonobis distance ------------------------------>>>>>>> 0.15248177647187833
# features2_shape (49, 2048)
# 236 mahalonobis distance ------------------------------>>>>>>> 0.15038307942094825
# features2_shape (49, 2048)
# 237 mahalonobis distance ------------------------------>>>>>>> 0.1522317820070106
# features2_shape (49, 2048)
# 238 mahalonobis distance ------------------------------>>>>>>> 0.1524537669962937
# features2_shape (49, 2048)
# 239 mahalonobis distance ------------------------------>>>>>>> 0.1537674960518547
# features2_shape (49, 2048)
# 240 mahalonobis distance ------------------------------>>>>>>> 0.150632412996777
# features2_shape (49, 2048)
# 241 mahalonobis distance ------------------------------>>>>>>> 0.149913353239009
# features2_shape (49, 2048)
# 242 mahalonobis distance ------------------------------>>>>>>> 0.14660018719408957
# features2_shape (49, 2048)
# 243 mahalonobis distance ------------------------------>>>>>>> 0.14633381961397157
# features2_shape (49, 2048)
# 244 mahalonobis distance ------------------------------>>>>>>> 0.14203951693448869
# features2_shape (49, 2048)
# 245 mahalonobis distance ------------------------------>>>>>>> 0.1414222372261973
# features2_shape (49, 2048)
# 246 mahalonobis distance ------------------------------>>>>>>> 0.13908866802325853
# features2_shape (49, 2048)
# 247 mahalonobis distance ------------------------------>>>>>>> 0.14719647818241943
# features2_shape (49, 2048)
# 248 mahalonobis distance ------------------------------>>>>>>> 0.14699290268226406
# features2_shape (49, 2048)
# 249 mahalonobis distance ------------------------------>>>>>>> 0.15135609602421818
# features2_shape (49, 2048)
# 250 mahalonobis distance ------------------------------>>>>>>> 0.15305462153072613
# features2_shape (49, 2048)
# 251 mahalonobis distance ------------------------------>>>>>>> 0.1508524764602311
# features2_shape (49, 2048)
# 252 mahalonobis distance ------------------------------>>>>>>> 0.14908063097084273
# features2_shape (49, 2048)
# 253 mahalonobis distance ------------------------------>>>>>>> 0.14026414295535178
# features2_shape (49, 2048)
# 254 mahalonobis distance ------------------------------>>>>>>> 0.1365926514759655
# features2_shape (49, 2048)
# 255 mahalonobis distance ------------------------------>>>>>>> 0.1363416198623389
# features2_shape (49, 2048)
# 256 mahalonobis distance ------------------------------>>>>>>> 0.13165978019818286
# features2_shape (49, 2048)
# 257 mahalonobis distance ------------------------------>>>>>>> 0.13076683778142167
# features2_shape (49, 2048)
# 258 mahalonobis distance ------------------------------>>>>>>> 0.10716550854575174
# features2_shape (49, 2048)
# 259 mahalonobis distance ------------------------------>>>>>>> 0.11757891395690395
# features2_shape (49, 2048)
# 260 mahalonobis distance ------------------------------>>>>>>> 0.1139506935079822
# features2_shape (49, 2048)
# 261 mahalonobis distance ------------------------------>>>>>>> 0.112434823204354
# features2_shape (49, 2048)
# 262 mahalonobis distance ------------------------------>>>>>>> 0.11357729142832895
# features2_shape (49, 2048)
# 263 mahalonobis distance ------------------------------>>>>>>> 0.11174281250052831
# features2_shape (49, 2048)
# 264 mahalonobis distance ------------------------------>>>>>>> 0.114248538242184
# features2_shape (49, 2048)
# 265 mahalonobis distance ------------------------------>>>>>>> 0.15339860473935762
# features2_shape (49, 2048)
# 266 mahalonobis distance ------------------------------>>>>>>> 0.15442715659727146
# features2_shape (49, 2048)
# 267 mahalonobis distance ------------------------------>>>>>>> 0.1556054244619524
# features2_shape (49, 2048)
# 268 mahalonobis distance ------------------------------>>>>>>> 0.15308717047265819
# features2_shape (49, 2048)
# 269 mahalonobis distance ------------------------------>>>>>>> 0.1546514413666406
# features2_shape (49, 2048)
# 270 mahalonobis distance ------------------------------>>>>>>> 0.1544942672315609
# features2_shape (49, 2048)
# 271 mahalonobis distance ------------------------------>>>>>>> 0.1520767179597216
# features2_shape (49, 2048)
# 272 mahalonobis distance ------------------------------>>>>>>> 0.15289750431895716
# features2_shape (49, 2048)
# 273 mahalonobis distance ------------------------------>>>>>>> 0.15712410519998848
# features2_shape (49, 2048)
# 274 mahalonobis distance ------------------------------>>>>>>> 0.15361425577897014
# features2_shape (49, 2048)
# 275 mahalonobis distance ------------------------------>>>>>>> 0.15582023222436509
# features2_shape (49, 2048)
# 276 mahalonobis distance ------------------------------>>>>>>> 0.1545511568907489
# features2_shape (49, 2048)
# 277 mahalonobis distance ------------------------------>>>>>>> 0.1539519875557313
# features2_shape (49, 2048)
# 278 mahalonobis distance ------------------------------>>>>>>> 0.15413033399238713
# features2_shape (49, 2048)
# 279 mahalonobis distance ------------------------------>>>>>>> 0.15384381271187297
# features2_shape (49, 2048)
# 280 mahalonobis distance ------------------------------>>>>>>> 0.15400839584576237
# features2_shape (49, 2048)
# 281 mahalonobis distance ------------------------------>>>>>>> 0.1492907583205944
# features2_shape (49, 2048)
# 282 mahalonobis distance ------------------------------>>>>>>> 0.13858252242096625
# features2_shape (49, 2048)
# 283 mahalonobis distance ------------------------------>>>>>>> 0.13154225393614194
# features2_shape (49, 2048)
# 284 mahalonobis distance ------------------------------>>>>>>> 0.1104645467054613
# features2_shape (49, 2048)
# 285 mahalonobis distance ------------------------------>>>>>>> 0.1291660170673043
# features2_shape (49, 2048)
# 286 mahalonobis distance ------------------------------>>>>>>> 0.09407995996929608
# features2_shape (49, 2048)
# 287 mahalonobis distance ------------------------------>>>>>>> 0.12683498741635252
# features2_shape (49, 2048)
# 288 mahalonobis distance ------------------------------>>>>>>> 0.09752740291279782
# features2_shape (49, 2048)
# 289 mahalonobis distance ------------------------------>>>>>>> 0.11213772243107878
# features2_shape (49, 2048)
# 290 mahalonobis distance ------------------------------>>>>>>> 0.11736055600201045
# features2_shape (49, 2048)
# 291 mahalonobis distance ------------------------------>>>>>>> 0.12604554166377846
# features2_shape (49, 2048)
# 292 mahalonobis distance ------------------------------>>>>>>> 0.1281915204876526
# features2_shape (49, 2048)
# 293 mahalonobis distance ------------------------------>>>>>>> 0.11698475092237653
# features2_shape (49, 2048)
# 294 mahalonobis distance ------------------------------>>>>>>> 0.09609502489953214
# features2_shape (49, 2048)
# 295 mahalonobis distance ------------------------------>>>>>>> 0.10340247398443131
# features2_shape (49, 2048)
# 296 mahalonobis distance ------------------------------>>>>>>> 0.08238821030894405
# features2_shape (49, 2048)
# 297 mahalonobis distance ------------------------------>>>>>>> 0.08731404336687965
# features2_shape (49, 2048)
# 298 mahalonobis distance ------------------------------>>>>>>> 0.15121006988917285
# features2_shape (49, 2048)
# 299 mahalonobis distance ------------------------------>>>>>>> 0.15104042332123568
# features2_shape (49, 2048)
# 300 mahalonobis distance ------------------------------>>>>>>> 0.15364245410067762
# features2_shape (49, 2048)
# 301 mahalonobis distance ------------------------------>>>>>>> 0.15233627119306303
# features2_shape (49, 2048)
# 302 mahalonobis distance ------------------------------>>>>>>> 0.1517343747823529
# features2_shape (49, 2048)
# 303 mahalonobis distance ------------------------------>>>>>>> 0.15035714970999248
# features2_shape (49, 2048)
# 304 mahalonobis distance ------------------------------>>>>>>> 0.15060672308630596
# features2_shape (49, 2048)
# 305 mahalonobis distance ------------------------------>>>>>>> 0.15035714970999248
# features2_shape (49, 2048)
# 306 mahalonobis distance ------------------------------>>>>>>> 0.15136007334133122
# features2_shape (49, 2048)
# 307 mahalonobis distance ------------------------------>>>>>>> 0.1506710128152216
# features2_shape (49, 2048)
# 308 mahalonobis distance ------------------------------>>>>>>> 0.149915140848768
# features2_shape (49, 2048)
# 309 mahalonobis distance ------------------------------>>>>>>> 0.149657775678448
# features2_shape (49, 2048)
# 310 mahalonobis distance ------------------------------>>>>>>> 0.14822462573104328
# features2_shape (49, 2048)
# 311 mahalonobis distance ------------------------------>>>>>>> 0.15025968412585922
# features2_shape (49, 2048)
# 312 mahalonobis distance ------------------------------>>>>>>> 0.15583001237628435
# features2_shape (49, 2048)
# 313 mahalonobis distance ------------------------------>>>>>>> 0.1562531515773865
# features2_shape (49, 2048)
# 314 mahalonobis distance ------------------------------>>>>>>> 0.1580703694972344
# features2_shape (49, 2048)
# 315 mahalonobis distance ------------------------------>>>>>>> 0.15839397819325968
# features2_shape (49, 2048)
# 316 mahalonobis distance ------------------------------>>>>>>> 0.14982721190231862
# features2_shape (49, 2048)
# 317 mahalonobis distance ------------------------------>>>>>>> 0.14590689069347484
# features2_shape (49, 2048)
# 318 mahalonobis distance ------------------------------>>>>>>> 0.14410671448895673
# features2_shape (49, 2048)
# 319 mahalonobis distance ------------------------------>>>>>>> 0.15092341148917748
# features2_shape (49, 2048)
# 320 mahalonobis distance ------------------------------>>>>>>> 0.15019734895888776
# features2_shape (49, 2048)
# 321 mahalonobis distance ------------------------------>>>>>>> 0.153135559317726
# features2_shape (49, 2048)
# 322 mahalonobis distance ------------------------------>>>>>>> 0.15303762629390594
# features2_shape (49, 2048)
# 323 mahalonobis distance ------------------------------>>>>>>> 0.15787665318285893
# features2_shape (49, 2048)
# 324 mahalonobis distance ------------------------------>>>>>>> 0.15683514112296493
# features2_shape (49, 2048)
# 325 mahalonobis distance ------------------------------>>>>>>> 0.1575229146470979
# features2_shape (49, 2048)
# 326 mahalonobis distance ------------------------------>>>>>>> 0.15818173487751774
# features2_shape (49, 2048)
# 327 mahalonobis distance ------------------------------>>>>>>> 0.15818173487751774
# features2_shape (49, 2048)
# 328 mahalonobis distance ------------------------------>>>>>>> 0.1571066295722484
# features2_shape (49, 2048)
# 329 mahalonobis distance ------------------------------>>>>>>> 0.1570599438093211
# features2_shape (49, 2048)
# 330 mahalonobis distance ------------------------------>>>>>>> 0.1574103564671167
# features2_shape (49, 2048)
# 331 mahalonobis distance ------------------------------>>>>>>> 0.15620143574083117
# features2_shape (49, 2048)
# 332 mahalonobis distance ------------------------------>>>>>>> 0.15503605306825397
# features2_shape (49, 2048)
# 333 mahalonobis distance ------------------------------>>>>>>> 0.14618123136079125
# features2_shape (49, 2048)
# 334 mahalonobis distance ------------------------------>>>>>>> 0.1109299319374698
# features2_shape (49, 2048)
# 335 mahalonobis distance ------------------------------>>>>>>> 0.11581884661618042
# features2_shape (49, 2048)
# 336 mahalonobis distance ------------------------------>>>>>>> 0.13866632275006274
# features2_shape (49, 2048)
# 337 mahalonobis distance ------------------------------>>>>>>> 0.15050647224193697
# features2_shape (49, 2048)
# 338 mahalonobis distance ------------------------------>>>>>>> 0.15698629139873055
# features2_shape (49, 2048)
# 339 mahalonobis distance ------------------------------>>>>>>> 0.15698629139873055
# features2_shape (49, 2048)
# 340 mahalonobis distance ------------------------------>>>>>>> 0.14915601935943956
# features2_shape (49, 2048)
# 341 mahalonobis distance ------------------------------>>>>>>> 0.14609809248793382
# features2_shape (49, 2048)
# 342 mahalonobis distance ------------------------------>>>>>>> 0.14458864044420017
# features2_shape (49, 2048)
# 343 mahalonobis distance ------------------------------>>>>>>> 0.1507936681754804
# features2_shape (49, 2048)
# 344 mahalonobis distance ------------------------------>>>>>>> 0.1443788947578013
# features2_shape (49, 2048)
# 345 mahalonobis distance ------------------------------>>>>>>> 0.14099759658235161
# features2_shape (49, 2048)
# 346 mahalonobis distance ------------------------------>>>>>>> 0.14724990827560752
# features2_shape (49, 2048)
# 347 mahalonobis distance ------------------------------>>>>>>> 0.1509729760538025
# features2_shape (49, 2048)
# 348 mahalonobis distance ------------------------------>>>>>>> 0.143590464343555
# features2_shape (49, 2048)
# 349 mahalonobis distance ------------------------------>>>>>>> 0.1398964049315362
# features2_shape (49, 2048)
# 350 mahalonobis distance ------------------------------>>>>>>> 0.1372957858077602
# features2_shape (49, 2048)
# 351 mahalonobis distance ------------------------------>>>>>>> 0.1492702700414325
# features2_shape (49, 2048)
# 352 mahalonobis distance ------------------------------>>>>>>> 0.152027576203502
# features2_shape (49, 2048)
# 353 mahalonobis distance ------------------------------>>>>>>> 0.16055037119852356
# features2_shape (49, 2048)
# 354 mahalonobis distance ------------------------------>>>>>>> 0.1603271157878044
# features2_shape (49, 2048)
# 355 mahalonobis distance ------------------------------>>>>>>> 0.1504944840885863
# features2_shape (49, 2048)
# 356 mahalonobis distance ------------------------------>>>>>>> 0.15665251778794637
# features2_shape (49, 2048)
# 357 mahalonobis distance ------------------------------>>>>>>> 0.15244663297423117
# features2_shape (49, 2048)
# 358 mahalonobis distance ------------------------------>>>>>>> 0.14943337340301593
# features2_shape (49, 2048)
# 359 mahalonobis distance ------------------------------>>>>>>> 0.15093141493144185
# features2_shape (49, 2048)
# 360 mahalonobis distance ------------------------------>>>>>>> 0.14822233458708822
# features2_shape (49, 2048)
# 361 mahalonobis distance ------------------------------>>>>>>> 0.1583950975895691
# features2_shape (49, 2048)
# 362 mahalonobis distance ------------------------------>>>>>>> 0.15658868631108536
# features2_shape (49, 2048)
# 363 mahalonobis distance ------------------------------>>>>>>> 0.15628812229024053
# features2_shape (49, 2048)
# 364 mahalonobis distance ------------------------------>>>>>>> 0.1542078418566783
# features2_shape (49, 2048)
# 365 mahalonobis distance ------------------------------>>>>>>> 0.16017963739200536
# features2_shape (49, 2048)
# 366 mahalonobis distance ------------------------------>>>>>>> 0.14572402091937275
# features2_shape (49, 2048)
# 367 mahalonobis distance ------------------------------>>>>>>> 0.16304975701088692
# features2_shape (49, 2048)
# 368 mahalonobis distance ------------------------------>>>>>>> 0.16116099982753718
# features2_shape (49, 2048)
# 369 mahalonobis distance ------------------------------>>>>>>> 0.15798513428579863
# features2_shape (49, 2048)
# 370 mahalonobis distance ------------------------------>>>>>>> 0.15605778482827987
# features2_shape (49, 2048)
# 371 mahalonobis distance ------------------------------>>>>>>> 0.1568568329346855
# features2_shape (49, 2048)
# 372 mahalonobis distance ------------------------------>>>>>>> 0.16035294259373817
# features2_shape (49, 2048)
# 373 mahalonobis distance ------------------------------>>>>>>> 0.15587148402508294
# features2_shape (49, 2048)
# 374 mahalonobis distance ------------------------------>>>>>>> 0.15904956877878496
# features2_shape (49, 2048)
# 375 mahalonobis distance ------------------------------>>>>>>> 0.15078007426459122
# features2_shape (49, 2048)
# 376 mahalonobis distance ------------------------------>>>>>>> 0.15327788589708313
# features2_shape (49, 2048)
# 377 mahalonobis distance ------------------------------>>>>>>> 0.1494607654789542
# features2_shape (49, 2048)
# 378 mahalonobis distance ------------------------------>>>>>>> 0.15282362308842157
# features2_shape (49, 2048)
# 379 mahalonobis distance ------------------------------>>>>>>> 0.15895038646770204
# features2_shape (49, 2048)
# 380 mahalonobis distance ------------------------------>>>>>>> 0.15933996352123297
# features2_shape (49, 2048)
# 381 mahalonobis distance ------------------------------>>>>>>> 0.1536351096977845
# features2_shape (49, 2048)
# 382 mahalonobis distance ------------------------------>>>>>>> 0.14529983733651092
# features2_shape (49, 2048)
# 383 mahalonobis distance ------------------------------>>>>>>> 0.15476887114591237
# features2_shape (49, 2048)
# 384 mahalonobis distance ------------------------------>>>>>>> 0.1517119574857717
# features2_shape (49, 2048)
# 385 mahalonobis distance ------------------------------>>>>>>> 0.15242119251131886
# features2_shape (49, 2048)
# 386 mahalonobis distance ------------------------------>>>>>>> 0.15065121690374583
# features2_shape (49, 2048)
# 387 mahalonobis distance ------------------------------>>>>>>> 0.1506830500873914
# features2_shape (49, 2048)
# 388 mahalonobis distance ------------------------------>>>>>>> 0.14703904915628518
# features2_shape (49, 2048)
# 389 mahalonobis distance ------------------------------>>>>>>> 0.15353983767917123
# features2_shape (49, 2048)
# 390 mahalonobis distance ------------------------------>>>>>>> 0.1496237682204707
# features2_shape (49, 2048)
# 391 mahalonobis distance ------------------------------>>>>>>> 0.15439501746796336
# features2_shape (49, 2048)
# 392 mahalonobis distance ------------------------------>>>>>>> 0.15451155416592322
# features2_shape (49, 2048)
# 393 mahalonobis distance ------------------------------>>>>>>> 0.15735417080597147
# features2_shape (49, 2048)
# 394 mahalonobis distance ------------------------------>>>>>>> 0.1538888742505638
# features2_shape (49, 2048)
# 395 mahalonobis distance ------------------------------>>>>>>> 0.15102584665904267
# features2_shape (49, 2048)
# 396 mahalonobis distance ------------------------------>>>>>>> 0.15519751837285056
# features2_shape (49, 2048)
# 397 mahalonobis distance ------------------------------>>>>>>> 0.15119234378540863
# features2_shape (49, 2048)
# 398 mahalonobis distance ------------------------------>>>>>>> 0.15336507460233118
# features2_shape (49, 2048)
# 399 mahalonobis distance ------------------------------>>>>>>> 0.14835708945862874
# features2_shape (49, 2048)
# 400 mahalonobis distance ------------------------------>>>>>>> 0.15068878639717403
# features2_shape (49, 2048)
# 401 mahalonobis distance ------------------------------>>>>>>> 0.15755444290083326
# features2_shape (49, 2048)
# 402 mahalonobis distance ------------------------------>>>>>>> 0.1503727842470567
# features2_shape (49, 2048)
# 403 mahalonobis distance ------------------------------>>>>>>> 0.15074691459753226
# features2_shape (49, 2048)
# 404 mahalonobis distance ------------------------------>>>>>>> 0.14328317344911107
# features2_shape (49, 2048)
# 405 mahalonobis distance ------------------------------>>>>>>> 0.12965977544682467
# features2_shape (49, 2048)
# 406 mahalonobis distance ------------------------------>>>>>>> 0.13916648815456573
# features2_shape (49, 2048)
# 407 mahalonobis distance ------------------------------>>>>>>> 0.14649564310503344
# features2_shape (49, 2048)
# 408 mahalonobis distance ------------------------------>>>>>>> 0.15356346905382373
# features2_shape (49, 2048)
# 409 mahalonobis distance ------------------------------>>>>>>> 0.15569477753346783
# features2_shape (49, 2048)
# 410 mahalonobis distance ------------------------------>>>>>>> 0.15091321652312223
# features2_shape (49, 2048)
# 411 mahalonobis distance ------------------------------>>>>>>> 0.1478831927255495
# features2_shape (49, 2048)
# 412 mahalonobis distance ------------------------------>>>>>>> 0.1435074200811003
# features2_shape (49, 2048)
# 413 mahalonobis distance ------------------------------>>>>>>> 0.15273289304837306
# features2_shape (49, 2048)
# 414 mahalonobis distance ------------------------------>>>>>>> 0.14907886988225727
# features2_shape (49, 2048)
# 415 mahalonobis distance ------------------------------>>>>>>> 0.14384779768704598
# features2_shape (49, 2048)
# 416 mahalonobis distance ------------------------------>>>>>>> 0.12634744852546226
# features2_shape (49, 2048)
# 417 mahalonobis distance ------------------------------>>>>>>> 0.1188580536662946
# features2_shape (49, 2048)
# 418 mahalonobis distance ------------------------------>>>>>>> 0.12198010366763645
# features2_shape (49, 2048)
# 419 mahalonobis distance ------------------------------>>>>>>> 0.12057469994993558
# features2_shape (49, 2048)
# 420 mahalonobis distance ------------------------------>>>>>>> 0.12138685903094815
# features2_shape (49, 2048)
# 421 mahalonobis distance ------------------------------>>>>>>> 0.10693930038398641
# CPU times: user 4min 20s, sys: 1min 12s, total: 5min 33s
# Wall time: 53.1 s
# (422,)

# %%
min(dist_list)

# %%
# %%time

################### Test per patch ###########################
test_image = load_images_from_folder("/home/ws575033/thesis_nb/Data_set/grid_values/cross/")
print("Test_image", test_image.shape)
dist_list=[]
for i in range(len(test_image)):
    tes = test_image[i]
    tes = np.expand_dims(tes, axis=0)
    #extract features
    features2 = intermediate_layer_modelb4.predict(
    tes,
    batch_size=None,
    verbose=0,
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
    )
    #print(features2.shape)

    #for i in range(features2.shape[0]):
    
    features2_linear = features2.reshape(-1, features2.shape[-1])
    print("features2_shape", features2_linear.shape)

    #Mahalonobis distance
    #maha = distance.cdist(gm.means_, features2_linear, 'mahalanobis', VI=inv_cov)
    maha = cls.decision_function(features2_linear)
    maha_new = maha.reshape(-1, 7)
    #seaborn.distplot(maha)
    #plt.imshow(maha)
    #seaborn.distplot(gm.means_)
    #plt.imshow(gm.means_)
    #print("mahalonobis distance shape", maha.shape)
    print("mahalonobis distance", maha.reshape(-1, 7))
    print(i, "mahalonobis distance ------------------------------>>>>>>>", maha.min())
    
    dist_list.append(maha)
dist_list = np.array(dist_list)
dist_list.shape

# %%
import pandas as pd
import seaborn as sns
a = dist_list.reshape(-1, 49)
x = pd.DataFrame(a)
b = x.T

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
e = pd.read_csv("/home/ws575033/thesis_nb/Data_set/grid_values/Results/hist.csv")

thresh = 50
plt.hist(e.Anomaly_Score, bins=75)
plt.axvline(x=thresh, color='r', linestyle='solid', linewidth=2)

# %%
# ######################## Heat Map ##########################

import pandas as pd
import seaborn as sns 
import dataframe_image as dfi 
import numpy as np  

for i in range(dist_list.shape[0]): 
    x = dist_list[i].reshape(7,7)
    fig = plt.figure()
#supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
    ax= sns.heatmap(x,vmin=-0.000001,vmax=0.00001,  cmap='Set1',annot=False,cbar=False)
    ax.axis('off')
    fig.set_size_inches(640/100,480/100)
    plt.tight_layout()
    #plt.show()
    fig.savefig(f"/home/ws575033/thesis_nb/Data_set/grid_values/res/cross{i}.jpg",pad_inches=0.1, dpi=100)

# %%
for file in os.listdir('/home/ws575033/thesis_nb/Data_set/grid_values/cross/'):
    n = file.split(".")[0]
    img1 = cv2.imread(f"/home/ws575033/thesis_nb/Data_set/grid_values/res/cross{n}.jpg")
    img2 = cv2.imread(f'/home/ws575033/thesis_nb/Data_set/grid_values/cross/{n}.jpg')

    body = img1[14:-14, 14:-14]

    width= 640
    hight= 480
    dim=(width, hight)
    img3 = cv2.resize(body, dim, interpolation=cv2.INTER_AREA)


    dst = cv2.addWeighted(img2,1.0,img3,0.5,0)

    cv2.imwrite(f"/home/ws575033/thesis_nb/Data_set/grid_values/res/cross_{n}.jpg", dst)
    plt.imshow(dst)

# %%
# import cv2
# import matplotlib.pyplot as plt
# def load_img_from_folder(folder):
#     img1 = []
#     img2 = []
#     for filename in tqdm(sorted(os.listdir(folder))):
#         img = cv2.imread(os.path.join(folder,filename))
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         img = cv2.resize(img, (224, 224))
#         if img is not None:
#             img1.append(img)
#             img2.append(img)
#     return np.array(images)

# path1 = load_img_from_folder("/home/ws575033/thesis_nb/Data_set/grid_values/res/")
# path2 = load_img_from_folder("/home/ws575033/thesis_nb/Data_set/grid_values/trolley1/")
# path.shape

# img1 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol0.jpg")
# img2 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/trolley1/1590668982109888984.jpg")

# body = img1[14:-14, 14:-14]

# width= 640
# hight= 480
# dim=(width, hight)
# img3 = cv2.resize(body, dim, interpolation=cv2.INTER_AREA)


# dst = cv2.addWeighted(img2,1.0,img3,0.5,0)

# cv2.imwrite("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol_0.jpg", dst)
# plt.imshow(dst)

# %%
# import pandas as pd
# import seaborn as sns
# import dataframe_image as dfi
# import numpy as np

# d = pd.DataFrame(dist_list[0].reshape(7,7))

# # displaying dataframe as an heatmap 
# # with diverging colourmap as virdis
# fig = plt.figure()
# #supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
# ax= sns.heatmap(d,cmap='Purples_r',annot=False,cbar=False) #icefire, magma_r, pink, _r, Purples_r, RdYlGn_r
# ax.axis('off')
# fig.set_size_inches(640/100,480/100)
# plt.tight_layout()
# plt.show()
# fig.savefig("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol0.jpg",pad_inches=0.1, dpi=100) #,bbox_inches='tight'

# %%
# import cv2
# import matplotlib.pyplot as plt


# img1 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol0.jpg")
# img2 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/trolley1/1590668982109888984.jpg")

# body = img1[14:-14, 14:-14]

# width= 640
# hight= 480
# dim=(width, hight)
# img3 = cv2.resize(body, dim, interpolation=cv2.INTER_AREA)


# dst = cv2.addWeighted(img2,1.0,img3,0.5,0)

# cv2.imwrite("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol_0.jpg", dst)
# plt.imshow(dst)

# %%
########################### Make video  ################################

import cv2
import numpy as np
import glob
 
img_array = []
for filename in glob.glob('/home/ws575033/thesis_nb/Data_set/grid_values/Results/video/MVG/Trolley/*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 
 
out = cv2.VideoWriter('/home/ws575033/thesis_nb/Data_set/grid_values/Results/video/MVG/Trolley/project.avi',cv2.VideoWriter_fourcc(*'DIVX'), 15, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()

# %%
import cv2 # pip install opencv-python
import os
from o.path import isfile,join
def convert_pictures_to_video(pathIn,pathout,fps,time):

    frame_array=[]
    files=[f for f in os.listdir(pathIn)if isfile(join(pathIn,f))]
    for i in range (len(files)):
        filename=pathIn+files[i]

        img=cv2.imread(filename)
        height,width,layers=img.shape
        size=(width,height)
    
        for k in range (time):
            frame_array.append(img)
    out=cv2.Videowriter(pathout,cv2.Videowriter_fourcc(*'mp4v',fps,size))
    for i in range(len(frame_array)):
        out.write(frame_array[i])
    out.release(


directory=(r'/home/ws575033/thesis_nb/Data_set/grid_values/Results/video/MVG/Trolley')
pathIn=directory+'/*.jpg'
pathout=pathIn+'video_EX9.avi'
fps=1
time=20 # the duration of each picture in the video
convert_pictures_to_video(pathIn,pathout,fps,time)

# %%
import cv2
import numpy as np
import glob

frameSize = (480, 640)

out = cv2.VideoWriter('output_video.mp4',cv2.VideoWriter_fourcc(*'DIVX'), 1, frameSize)

for filename in glob.glob('/home/ws575033/thesis_nb/Data_set/grid_values/Results/video/MVG/Trolley/*.jpg'):
    img = cv2.imread(filename)
    out.write(img)

out.release()

# %%
######################## Data Frame for seq of images ##########################

import pandas as pd
d = pd.DataFrame()
for i in range(7):
    d[str(i)] = maha.reshape(7,7)[:,i]
d

# %%
######################## Data Frame ##########################


import pandas as pd
d = pd.DataFrame()
for i in range(7):
    d[str(i)] = maha.reshape(7,7)[:,i]
d

import pandas as pd
import numpy as np

def highlight_max(s):
    is_max = s == maha.min()
    return ['background-color: red' if v else '' for v in is_max]

d.style.apply(highlight_max)

# %%
# ######################## Heat Map ##########################

# import pandas as pd
# import seaborn as sns
# import dataframe_image as dfi


# # displaying dataframe as an heatmap 
# # with diverging colourmap as virdis
# fig = plt.figure()
# #supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
# ax= sns.heatmap(d,cmap='icefire',annot=False,cbar=False) #icefire, magma_r, pink, _r, turbo_r
# ax.axis('off')
# fig.set_size_inches(640/100,480/100)
# plt.tight_layout()
# plt.show()
# fig.savefig("/home/ws575033/thesis_nb/Data_set/grid_values/res/troll1.jpg",pad_inches=0.1, dpi=100) #,bbox_inches='tight'

# %%
# import cv2
# import matplotlib.pyplot as plt


# img1 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/res/troll1.jpg")
# img2 = cv2.imread("/home/ws575033/thesis_nb/Data_set/grid_values/trolley1/1590668982109888984.jpg")

# body = img1[14:-14, 14:-14]

# width= 640
# hight= 480
# dim=(width, hight)
# img3 = cv2.resize(body, dim, interpolation=cv2.INTER_AREA)


# dst = cv2.addWeighted(img2,1.0,img3,0.5,0)

# cv2.imwrite("/home/ws575033/thesis_nb/Data_set/grid_values/res/troll_g.jpg", dst)
# plt.imshow(dst)

# %%
# import cv2
# import numpy as np
# from PIL import Image
# import matplotlib.pyplot as plt
    
# # Take two images for blending them together   
# image1 = Image.open('/home/ws575033/thesis_nb/Data_set/grid_values/trolley1/1590668982109888984.jpg')
# image2 = Image.open("/home/ws575033/thesis_nb/Data_set/grid_values/res/trol1.jpg")

# # Make sure images got an alpha channel
# image5 = image1.convert("RGBA")
# image6 = image2.convert("RGBA")


# # alpha-blend the images with varying values of alpha
# alphaBlended = Image.blend(image5, image6, alpha=.4)

# # Display the alpha-blended images
# #alphaBlended.show()
# plt.savefig('/home/ws575033/thesis_nb/Data_set/grid_values/res/trol1_F.jpg', bbox_inches='tight')
# plt.imshow(alphaBlended)

# %%
# import matplotlib.pyplot as plt
# from skimage import data
# from skimage.filters import threshold_otsu, threshold_mean, threshold_triangle
# from skimage.color import rgb2gray

# test_image = load_images_from_folder("Test2/")
# test_image = rgb2gray(test_image[0])
# #thresh = threshold_triangle(test_image)
# #binary = test_image > thresh

# fig, axes = plt.subplots(ncols=3, figsize=(8, 2.5))
# ax = axes.ravel()
# ax[0] = plt.subplot(1, 3, 1)
# ax[1] = plt.subplot(1, 3, 2)
# ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

# ax[0].imshow(test_image, cmap=plt.cm.gray)
# ax[0].set_title('Original')
# ax[0].axis('off')

# ax[1].hist(test_image.ravel(), bins=256)
# ax[1].set_title('Histogram')
# ax[1].axvline(thresh, color='r')

# ax[2].imshow(binary, cmap=plt.cm.gray)
# ax[2].set_title('Thresholded')
# ax[2].axis('off')

# plt.show()

# %%
import os
def load_folder_rgb(path, ext="jpg", sz=(224, 224)):
    files= os.listdir(path)
    result = []
    for file in files:
        if ext in file:
            img=cv2.imread(path+file)
            img = cv2.resize(img, sz)
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_hsv=cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)
            result.append(img_hsv)

    return np.array(result)

# %%
import matplotlib.pyplot as plt
from skimage import data
from skimage.filters import threshold_otsu, threshold_mean, threshold_triangle, threshold_minimum
from skimage.color import rgb2gray

#test_image = load_images_from_folder("Test1/")
img=cv2.imread("/home/ws575033/thesis_nb/Test1/1590667323098235798.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv=cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)

# lower mask (0-10)
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)

# upper mask (170-180)
lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)

# join my masks
mask = mask0+mask1

# set my output img to zero everywhere except my mask
output_img = img_rgb.copy()
output_img[np.where(mask==0)] = 0

opt_img= rgb2gray(img_rgb)
thresh = threshold_minimum(opt_img)
binary = opt_img > thresh

fig, axes = plt.subplots(ncols=3, figsize=(16, 5))
ax = axes.ravel()
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

ax[0].imshow(img_rgb, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')

ax[1].hist(opt_img.ravel(), bins=100)
ax[1].set_title('Histogram')
ax[1].axvline(thresh, color='r')

ax[2].imshow(output_img)
ax[2].set_title('Mask')
ax[2].axis('off')

plt.show()

# %%
arr = np.array(maha)
arr.max(), arr.min()

# %%
if maha.max()>17:
  print("ANOMALY")
else:
  print("NO ANOMALY")

# %%
output = arr.max()>100

# %%
########################################### METRICS ################################################

# %%
########################################### per frame ################################################
import pandas as pd
from sklearn.metrics import accuracy_score
p = pd.read_csv("/home/ws575033/thesis_nb/test_fin.csv")
p.head()
p.labels
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 417    1
# 418    1
# 419    1
# 420    1
# 421    1
# Name: labels, Length: 422, dtype: int64

# %%
########################################### per patch ################################################
import pandas as pd
from sklearn.metrics import accuracy_score
p = pd.read_csv("/home/ws575033/thesis_nb/Data_set/grid_values/cross.csv")
p.head()

# %%
#################################### AUC_ROC curve ########################

import numpy as np

def roc_curve_calculation(y_true, prediction, thresholds):

    fpr = []
    tpr = []
    acc = []

    for threshold in thresholds:

        y_pred = np.where(prediction <= threshold, 1, 0)

        fp = np.sum((y_pred == 1) & (y_true == 0))
        tp = np.sum((y_pred == 1) & (y_true == 1))

        fn = np.sum((y_pred == 0) & (y_true == 1))
        tn = np.sum((y_pred == 0) & (y_true == 0))

        fpr.append(fp / (fp + tn))
        tpr.append(tp / (tp + fn))
        

    return fpr, tpr

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import accuracy_score
import numpy as np

a= np.arange(-5, 10,0.0001)
acc = []
ktf = []
rtf = []
fpr_list = []
tpr_list = []

fpr, tpr = roc_curve_calculation(p.values.flatten(), d.values.flatten(), a)
# import pickle
# filename = 'if_Xception_fpr'
# outfile = open(filename,'wb')
# pickle.dump(fpr,outfile)
# outfile.close()

# filename = 'if_Xception_tpr'
# outfile = open(filename,'wb')
# pickle.dump(tpr,outfile)
# outfile.close()

roc_auc = auc(fpr, tpr)
#plt.figure()
lw = 2

plt.plot(fpr,tpr,color='blue',
             lw=lw, label='ROC curve (area = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (MobilenetV2) ')
plt.legend(loc="lower right") 
plt.show()

# %%
tpr

# %%
fpr

# %%
# from sklearn.metrics import roc_curve, auc
# from sklearn.metrics import RocCurveDisplay
# from sklearn.metrics import accuracy_score
# import numpy as np

# a= np.arange(0, 5000, 10)

# cntr = 0
# acc = []
# ktf = []
# rtf = []
# fpr = dict()
# tpr = dict()
# curves = dict()
# roc_auc = dict()


# for c in a:
#     kt = d>c
#     kt  = kt.values.flatten()
#     ktf.append(kt)
#     rtf.append(p.values.flatten())
#     #rint(kt.shape)
#     acc.append(accuracy_score(kt,p.values.flatten()))
# for i in range(len(ktf)):
#     fpr[i], tpr[i], _ = roc_curve(rtf[i], ktf[i])
#     roc_auc[i] = auc(fpr[i], tpr[i])
# #print(acc)
# l = max(acc)
# ac = acc.index(l)
# #print(ac)
# print(max(acc))
# #plt.figure()
# lw = 2
# plt.plot(fpr[ac],tpr[ac],color='darkorange',
#              lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[ac])
# plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic (MobileNetV2) ')
# plt.legend(loc="lower right")
# plt.show()

# %%
import pandas as pd
d = {'Threshold_values':a,'Accuracy':acc, 'Test_values':rtf, 'Test_scores':ktf}
df = pd.DataFrame(d)
df

# %%
import pandas as pd

df.to_csv("/home/ws575033/thesis_nb/Data_set/grid_values/Results/data_sheet.csv")

# %%
# from sklearn.metrics import roc_curve, auc
# from sklearn.metrics import RocCurveDisplay
# from sklearn.metrics import accuracy_score

# count = 0
# ktf = []
# rtf = [] 
# for i in range(10,80,1):
#     count+=0.5
#     #print(p.values.flatten().shape, d.values.flatten().clip(i).shape)
#     # fpr, tpr, _ = roc_curve(, )
    
#     ktf.extend(p.values.flatten())
#     rtf.extend(d.values.flatten().clip(count))
        
# fpr, tpr, _ = roc_curve(ktf, rtf)
# roc_curve = auc(tpr, fpr)
# plt.figure()
# lw = 2
# plt.plot(fpr, tpr, color='darkorange',
#          lw=lw, label='ROC curve (area = %0.2f)' % roc_curve)
# plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic (EfficientNet_B4) ')
# plt.legend(loc="lower right")
# plt.show()

# %%
# acc = []
# for i in range(ktf):
#     accuracy_score(i, p.values.flatten())
#     print(i)
#     acc.append(accuracy_score)
#     acc

# %%
######### accuracy per pixel #########
acc = []

for i in range(-100, 100,1):
    
    axi = accuracy_score(d.values.flatten()<i, p.values.flatten())
    acc.append(axi)
    f = max(acc)
    g = acc.index(f)
g,f

# %%
######### f1_Score per pixel #########
from sklearn.metrics import f1_score
f1_score(d.values.flatten()<0.127, p.values.flatten(), zero_division=1)

# %%
######### f1_Score #########
from sklearn.metrics import f1_score
f1_score(ktf[ac], rtf[ac], zero_division=1)

# %%
######### confusion_matrix #########
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(p.values.flatten(), d.values.flatten())
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
######### Precision_curve #########
import numpy as np
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import pickle

precision, recall, thresholds = precision_recall_curve(p.labels, dist_list)


plt.figure(figsize=(7, 8))
plt.plot(recall, precision, color='blue', lw=2)
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
average_precision = average_precision_score(p.labels, dist_list)
average_precision
plt.title(
    'Average precision score, : AP={0:0.2f}'
    .format(average_precision))

filename = 'if_vgg16_p.lab'
outfile = open(filename,'wb')
pickle.dump(p.labels,outfile)
outfile.close()

filename = 'if_vgg16_dist'
outfile = open(filename,'wb')
pickle.dump(dist_list,outfile)
outfile.close()

# %%
average_precision
# Out:
# 0.6474469213691325

# %%
labels, np.asarray(dist_list>30, dtype=np.float)

# %%
p.values.flatten(), np.asarray(kt, dtype=np.float)

# %%
fpr, tpr, thr

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import RocCurveDisplay

fpr, tpr, _ = roc_curve(p.values.flatten(), kt)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (EfficientNet_B4) ')
plt.legend(loc="lower right")
plt.show()

#roc_auc

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

p = pd.read_csv("/home/ws575033/thesis_nb/Accuracy_mvg.csv")
p.head()

# %%
disp = plt.bar(p.Models, p.Accuracy)

plt.axhline(np.max(p.Accuracy), linestyle='--', color='y',
            label='Best score')
y_pos = range(len(p.Accuracy))
plt.xticks(y_pos, p.Models, rotation=90)
plt.title("MVG Accuracy per_frame")
max(p.Accuracy)

# %%
p = pd.read_csv("/home/ws575033/thesis_nb/Data_set/grid_values/Results/MVG/MVG_Accuracy.csv")

disp = plt.bar(p.Models, p.Accuracy)

plt.axhline(np.max(p.Accuracy), linestyle='--', color='y',
            label='Best score')
y_pos = range(len(p.Accuracy))
plt.xticks(y_pos, p.Models, rotation=90)
plt.title("MVG Accuracy per_frame")
max(p.Accuracy)
